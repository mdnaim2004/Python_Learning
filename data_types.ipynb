# %%
data_type = "Hello,World!"
print(data_type)
# Out:
# Hello,World!

# %%
a = 10
print(a)
# Out:
# 10

# %% [markdown]
# ---
# - in python datatype automitecally declare....
# ---

# %%
a = 10
b = "Hello"
c = True

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# bool
