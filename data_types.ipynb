# %%
data_type = "Hello,World!"
print(data_type)
# Out:
# Hello,World!

# %%
a = 10
print(a)
# Out:
# 10

# %% [markdown]
# ---
# - in python datatype automitecally declare....
# ---

# %%
a = 10
b = "Hello"
c = True

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# bool

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
b = 3.15
type(b)
# Out:
# float

# %%
c = "Hello"
type(c)
# Out:
# str

# %%
d = 'hi'
print(type(d))
# Out:
# <class 'str'>

# %%
e = '12345'
print(type(e))
# Out:
# <class 'str'>

# %%
f = True
print(type(f))
# Out:
# <class 'bool'>
