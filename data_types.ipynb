# %%
data_type = "Hello,World!"
print(data_type)
# Out:
# Hello,World!

# %%
a = 10
print(a)
# Out:
# 10

# %% [markdown]
# ---
# - in python datatype automitecally declare....
# ---

# %%
a = 10
b = "Hello"
c = True

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# bool

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
b = 3.15
type(b)
# Out:
# float

# %%
c = "Hello"
type(c)
# Out:
# str

# %%
d = 'hi'
print(type(d))
# Out:
# <class 'str'>

# %%
e = '12345'
print(type(e))
# Out:
# <class 'str'>

# %%
f = True
print(type(f))
# Out:
# <class 'bool'>

# %%
g = False
print(type(g))
# Out:
# <class 'bool'>

# %%
h = None
print(type(h))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ---
# - string types but blanks
# ---

# %%
i = ""
print(type(i))
# Out:
# <class 'str'>

# %% [markdown]
# ---
# - string types but empty
# ---

# %%
j = " "
print(type(j))
# Out:
# <class 'str'>

# %% [markdown]
# # Function + Datatypes

# %% [markdown]
# ---
# - Do Something ------   to ----- data
# - Function ----------------------Value
# ---

# %%
text = "hi"
num = 50

print(type(text))
print(type(num))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(len(text))
print(len(num))
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 print(len(text))
# ----> 2 print(len(num))
#
# TypeError: object of type 'int' has no len()

# %%
text = "hi"
print(text.upper())
# Out:
# HI

# %%
num = 50
print(num.upper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 num = 50
# ----> 2 print(num.upper())
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
num = 50
print(num.bit_length())
# Out:
# 6

# %%
text = "hi"
print(text.bit_length())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 text = "hi"
# ----> 2 print(text.bit_length())
#
# AttributeError: 'str' object has no attribute 'bit_length'

# %% [markdown]
# ```
#                  Data Types
# ────────────────────────────────────────
#
# ├── No Value
# │   └── NoneType
# │       └── None
#
#
# ├── Single Value
# │
# │   ├── Numeric
# │   │   ├── int        → 15
# │   │   ├── float      → 3.15
# │   │   └── complex    → 3 + 5j
# │   │
# │   ├── str            → "Hello"
# │   │
# │   ├── bool
# │   │   ├── True
# │   │   └── False
# │   │
# │   └── Date & Time
# │       ├── date       → 2026-12-25
# │       ├── time       → 18:05:30
# │       └── datetime   → 2026-12-25 18:05:30
#
#
# └── Multi-Values
#     ├── list      → [1, 2, 3]
#     ├── tuple     → (1, 2, 3)
#     ├── set       → {1, 2, 3}
#     ├── dict      → {"a": 1, "b": 2}
#     └── array     → array('i', [10, 20])
#
#     ```

# %% [markdown]
# # Data Types
# ---
# - **Each value has a data types**
#     - this helps python decided hoe to handle thr values
# - **It automitically detects data types**
# - **Dynamically detects data types**
# - **3 Catagorys:**
#     - **No values : -** None type
#     - **Single : -** int, str, bool, float, complex
#     - **Multiple : -** set, tuple, dict, list
#     - **values are object of a data type class.**

# %% [markdown]
# ## Assignment:
#     - create 5 variables

# %%
age = 21
height = 5.94159
name = "Naim"
is_student = True
complex_var = 2 + 3j

# %%
print(f"Age is :", age)
# Out:
# Age is : 21

# %%
print(f"Height is :", height)
# Out:
# Height is : 5.94159

# %%
print(f"your name is: ", name)
# Out:
# your name is:  Naim

# %%
print(f"are yoy student? : ",is_student)
# Out:
# are yoy student? :  True

# %%
print(f"the complex variable is : ", complex_var)
# Out:
# the complex variable is :  5

# %%
h = True
print(False or h)
# Out:
# True

# %%
t = True
f = False

if t == f:
    print(t)

elif t or f:
    print("F****C")

elif t or f:
    print("Im trying")
# Out:
# F****C
