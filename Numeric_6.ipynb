# %% [markdown]
# ---
# # Numeric data types
# ---

# %% [markdown]
# ---
# ### numeric
# ---
# - int --------> 5, -12, 1000 etc,
# - float ------> 4.13, -0.5, 1000.05 etc.
# - complex ----> 2+3j, 5-2j etc,
#
# ---

# %% [markdown]
# ---
# ## Types
# ---

# %%
x = 5
y = 5.7
z = 2+3j

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(type(z))
# Out:
# <class 'complex'>

# %%
print(x * 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(x * 3)
#
# NameError: name 'x' is not defined

# %%
x = "25"
x = int (x)
print(type(x))
print(x*3)
# Out:
# <class 'int'>
# 75

# %%
x = 3.24
print(int(x))
# Out:
# 3

# %%
x = 3

print(float(x))
# Out:
# 3.0

# %%
x = "3"

print(float(x))
# Out:
# 3.0

# %%
x = 10 # real part
y = 5 # immaginary part

print(complex(x,y))
# Out:
# (10+5j)

# %%
print(complex(y,x))
# Out:
# (5+10j)

# %% [markdown]
# ---
# # Math Operations part
# ---

# %%
x = 2
y = 3

# %%
add = x+y
print(add)
# Out:
# 5

# %%
sub = x-y
print(sub)
# Out:
# -1

# %%
mul = x*y
print(mul)
# Out:
# 6

# %%
div = x/y
print(div)
# Out:
# 0.6666666666666666

# %%
mod = x%y
print(mod)
# Out:
# 2

# %%
exp = x**y
print(exp)
# Out:
# 8

# %%
x = 2
x = x+1

# %%
print(x)
# Out:
# 3

# %%
x = 3
x = x+5

print(x)
# Out:
# 8

# %%
x = 3
x += 2

print(x)
# Out:
# 5

# %%
x = 2
x -= 1
print(x)
# Out:
# 1

# %% [markdown]
# ---
# ## Routing
# ---

# %%
print(2-10)
# Out:
# -8

# %%
# but in abs() function use it always positive numberof the values
print(abs(2-10))
# Out:
# 8

# %% [markdown]
# - Rounding the numbers

# %%
price = 35.5468779

round(price)
# Out:
# 36

# %%
import math
math.floor(price)
# Out:
# 35

# %%
math.ceil(price)
# Out:
# 36

# %%
round(price, 2)
# Out:
# 35.55

# %%
round(price, 1)
# Out:
# 35.5

# %%
math.trunc(price)  # cut of the decimal path....
# Out:
# 35

# %%
int(price)
# Out:
# 35

# %% [markdown]
# ---
# # int()  vs trunc()
# ---
# - if math are not imported , then using int()
# - if using import math then using trync(), it make intent cleary.

# %% [markdown]
# ---
# ---
# # Advance Math
# ---
# ---

# %% [markdown]
# ---
# ---
# ---
# ### Random
# ---

# %%
import random
random.random()
# Out:
# 0.4536015528326215

# %%
print(random.randint(1,6))
# Out:
# 5

# %%
x = 7.0
x.is_integer()
# Out:
# True

# %%
y = 7.1
y.is_integer()
# Out:
# False

# %%
x = 70
isinstance(x, int)
# Out:
# True

# %%
x = 70.50
isinstance(x, int)
# Out:
# False

# %%
x = 70.50
isinstance(x, float)
# Out:
# True

# %%
import random
x = random.randint(1, 101)

if x%2==0: print(f"the number {x} is EVEN")
else: print("Its ODD number")
# Out:
# the number 74 is EVEN
