# %% [markdown]
# # String...

# %% [markdown]
# ---
# ## Built -in Function
# ---

# %%
name = "Naim"
print(type(name))
# Out:
# <class 'str'>

# %%
age = 22
print(type(age))
# Out:
# <class 'int'>

# %%
print("Your age is : " + str(age))
# Out:
# Your age is : 22

# %%
age = age + 5

# %%
age = str(age)
print(type(age))
# Out:
# <class 'str'>
