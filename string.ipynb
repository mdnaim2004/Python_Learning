# %% [markdown]
# # String...

# %% [markdown]
# ---
# ## Built -in Function
# ---

# %% [markdown]
# ---
# ### Str()
# ---

# %%
name = "Naim"
print(type(name))
# Out:
# <class 'str'>

# %%
age = 22
print(type(age))
# Out:
# <class 'int'>

# %%
print("Your age is : " + str(age))
# Out:
# Your age is : 22

# %%
age = age + 5

# %%
age = str(age)
print(type(age))
# Out:
# <class 'str'>

# %% [markdown]
# ---
# ## Math
# ---

# %% [markdown]
# ---
# ### len()
# ---

# %%
password = "124ab"
print(len(password))
# Out:
# 5

# %%
if len(password) < 8:
    print("Your password is too short!")
# Out:
# Your password is too short!

# %% [markdown]
# ---
# ### Count()
# ---

# %%
text = """
python is easy to learn.
python is powerfull.
many people love python.
"""

print(text.count("python"))
# Out:
# 3

# %%
print(text.count("$"))
# Out:
# 0

# %% [markdown]
# ---
# # Transformation
# ---

# %% [markdown]
# ---
# ### replace()
# ---

# %%
price = "1234,56"
print(price.replace(",","."))
# Out:
# 1234.56

# %%
phone = "176-1234-56"
print(phone.replace("-","/"))
# Out:
# 176/1234/56

# %%
print(phone.replace("-", " "))
# Out:
# 176 1234 56

# %%
print(phone.replace("-",""))
# Out:
# 176123456

# %%
print(price.replace(",", ""))
# Out:
# 123456

# %% [markdown]
# ---
# ### Python challenge
#
# - convert the messy phone number into a clean number formate with only digits
# - "+49 (176) 123-4567" to 00491761234567
# ---

# %%
phn = "+49 (176) 123-4567"
print(phn.replace("+","00").replace(" ", "").replace("(","").replace(")","").replace("-",""))
# Out:
# 00491761234567

# %% [markdown]
# ---
# ### Join String
# ---

# %%
first_name = "Naim"
second_name = "Islam"
final_name = first_name + " " + second_name
print(final_name)
# Out:
# Naim Islam

# %%
folder = "/home/mdnaim2004/Naim/"
file = "report.csv"
full_file_path = folder + file
print(full_file_path)
# Out:
# /home/mdnaim2004/Naim/report.csv

# %%
foled = "/home/mdnaim2004/abc/"
file = "abc.csv"
full_path_of_file = folder + file
print(full_path_of_file)
# Out:
# /home/mdnaim2004/Naim/abc.csv

# %% [markdown]
# ---
# ### f-string
# ---
#
# - Formate string, its formating the print statemen also.

# %%
name = "Naim"
age = 22
is_student = False

print("My Name is :"+name+" , I am "+str(age)+" Years old, and student status is ="+str(is_student)+ ".")
print(f"My name is  {name}, i am {age} years old, and student status is {is_student}.")
# Out:
# My Name is :Naim , I am 22 Years old, and student status is =False.
# My name is  Naim, i am 22 years old, and student status is False.

# %% [markdown]
# ---
# - it is easyer, and very well.
# ---

# %%
print(f"My name is  {name}, i am {age} years old, and student status is {is_student}.")
# Out:
# My name is  Naim, i am 22 years old, and student status is False.

# %%
print(f" 2 + 3 = {2 + 3}")
# Out:
#  2 + 3 = 5

# %%
print(f"{{this is me}}")
# Out:
# {this is me}

# %% [markdown]
# ---
# ### split()
# ---

# %%
stamp = "2026-09-12 14:30"
print(stamp.split(" "))
# Out:
# ['2026-09-12', '14:30']

# %%
stamp = "2026-09-12"
print(stamp.split("-"))
# Out:
# ['2026', '09', '12']

# %%
csv_file = "1234,max,usa,1999-19-05,M"
print(csv_file.split(","))
# Out:
# ['1234', 'max', 'usa', '1999-19-05', 'M']

# %% [markdown]
# ---
# ### String Repetition
# ---

# %%
print("ha" * 3)
# Out:
# hahaha

# %%
print("ha" * 3)
print("================================")
# Out:
# hahaha
# ...

# %%
print("=" * 30)

# %%
print("*" * 30)
# Out:
# ******************************

# %%
print("#" * 20)
# Out:
# ####################

# %%
print("+" * 50)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---
# # Data Extraction
# ---
# ### Indexcing and Slicing
# ---

# %% [markdown]
# - (+) Positive indexcing start the value of 0 to (n-1)
# - (-) Negetive Indexcing start the value of -1 to (-n)

# %%
s = "Hi_There_this_is_string"
print(s)
# Out:
# Hi_There_this_is_string

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
print(s[4:])
# Out:
# here_this_is_string

# %%
print(s[7 : 9])
# Out:
# e_

# %%
n = "NAIM"
n[2:4]
# Out:
# 'IM'

# %%
n[2:3]
# Out:
# 'I'

# %%
text = "Python"

text[0]
# Out:
# 'P'

# %%
text[1]
# Out:
# 'y'

# %%
# last char
text[-6]
# Out:
# 'P'

# %%
text[-1]
# Out:
# 'n'

# %%
text[3]
# Out:
# 'h'

# %%
date = "2026-09-20"

# extract value

date[0:4]
# Out:
# '2026'

# %%
date[ :4]
# Out:
# '2026'

# %%
#extractc the month

date[5:7]
# Out:
# '09'

# %%
# Extract the day
date[8:]
# Out:
# '20'

# %%
date[ -2 : ]
# Out:
# '20'

# %%
date[ :-8]
# Out:
# '20'

# %% [markdown]
# ---
# ## strip
# ---

# %%
text = "Engineering"
