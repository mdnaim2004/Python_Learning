# %%
hight = max(34,56,74,12,54,23,67,89,30,99)
print(hight)
# Out:
# 99

# %%
hight = max([34,56,74,12,54,23,67,89,30,99])
print(hight)
# Out:
# 99

# %%
smallest = min([34,56,74,12,54,23,67,89,30,99])
print(smallest)
# Out:
# 12

# %%
hight = max(34,56,74,12,54,23,67,89,30,99)
smallest = min([34,56,74,12,54,23,67,89,30,99])

count = len([23,24,5,6,7,45,67,78,34])
print(hight, smallest, count)
# Out:
# 99 12 9
