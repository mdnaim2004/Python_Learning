# %% [markdown]
# # Input Function

# %%
input("Enter your name :")
# Out:
# 'Naim'

# %%
name = input("Enter your name : ")
print("You are ", name)
# Out:
# You are  Md Naim

# %% [markdown]
# ##

# %% [markdown]
# ---
# - Hard-coded Values
# -           vs
# - Dynamic Values
# ---

# %%
name = input("Enter your name :")
country = "Bangladesh"

print("You are ", name, "comes from", country)
# Out:
# You are  Mdnaim2004 comes from Bangladesh

# %% [markdown]
# ## Learn  the topic is...
# ---
# - print()
# - input()
# - comments()
# - variables
# ---
