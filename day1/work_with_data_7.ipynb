# %% [markdown]
# ---
# ## How to control flow
# ---

# %% [markdown]
# ## Control Flow Statement

# %% [markdown]
# ---
# - **control statement:** if, else, elif
# ---
#
# - **Loops:** for, while
# ---
# - **Break statemrnt:** break, pass, continue
# ---

# %% [markdown]
# ---
# ---
# # Boolean Expression
# ---
#
# ---
# - **Values:** True, False
# ---
# - **Functions:** bool(), any(), all(), isinstance()
# ---
# - **Comparison Operators:** ==, !=, <, >, >=, <=
# ---
# - **Logical Operators:** and, or, not
# ---
# - **Membership Operator:** in, not in
# ---
# - **identity Operators:** is, is not
# ---

# %% [markdown]
# ### Boolean

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(bool(123))
# Out:
# True

# %%
print(bool("HI"))
# Out:
# True

# %%
print(bool(0))
# Out:
# False

# %%
print(bool())
# Out:
# False

# %%
print(bool(""))
# Out:
# False

# %%
None

# %%
print(bool(None))
# Out:
# False

# %% [markdown]
# ---
# ### any()
# ---

# %% [markdown]
# - if one value is exist it is true.

# %%
email = ""
phone = "01789-545804"
username = ""
print(any([email, phone, username]))
# Out:
# True

# %% [markdown]
# - there is no value the it can show False

# %%
email = ""
phone = ""
username = ""
print(any([email, phone, username]))
# Out:
# False

# %% [markdown]
# ---
# ### all()
# ---

# %% [markdown]
# - it must fullfill the requertment of the varivable. otherwise not working

# %%
email = "abc@gmail.com"
phone = "01789545804"
username = "abc"
print(all([email, phone, username]))
# Out:
# True

# %%
email = "abdajh"
phone = "1643587"
username = ""
print(all([email, phone, username]))
# Out:
# False

# %%
email = ""
phone = ""
username = ""
print(all([email, phone, username]))
# Out:
# False

# %%
isinstance(1234, int)
# Out:
# True

# %%
print(isinstance(True, str))
# Out:
# False

# %%
"Hello".endswith("o")
# Out:
# True

# %% [markdown]
# ---
# ---
# ## Comperison Operators
# ---

# %% [markdown]
# - values operator value ? true or false

# %%
3 > 2
# Out:
# True

# %%
3>4
# Out:
# False

# %%
3-2 != 2
# Out:
# True

# %%
3 == 5-2
# Out:
# True

# %%
5 != 5*2 - 5
# Out:
# False

# %%
print(type(10 == 10))
# Out:
# <class 'bool'>

# %%
print(10 == 10)
# Out:
# True

# %%
print(10!= 10)
# Out:
# False

# %%
print( 7 > 3)
print( 7 >= 3)
# Out:
# True
# True

# %%
print(3 < 7)
# Out:
# True

# %%
print(7 <= 7)
# Out:
# True

# %%
print("a" < "b")
# Out:
# True

# %%
"a" == "b"
# Out:
# False

# %%
"A" == "a"
# Out:
# False

# %% [markdown]
# ---
# - one = is assing the value, and
# - == is xomparisom the the value

# %%
print(1 < 4 < 6)
# Out:
# True

# %%
age = 20
18 <= age <= 30
# Out:
# True

# %%
age = 35
18 <= age <= 30
# Out:
# False

# %% [markdown]
# ---
# ---
# ## The Logical Operators
# ---

# %% [markdown]
# - and
# - or
# - not
# ---

# %%
3 < 5 and  5==5
# Out:
# True

# %%
3 < 5 or  5==5
# Out:
# True

# %%
3 < 5 or  5!=5
# Out:
# True

# %%
3 > 1 and 5<1
# Out:
# False

# %%
3 > 1 and 5>1
# Out:
# True

# %%
3 > 1 or 5<1
# Out:
# True

# %%
3 > 1 or 5>1
# Out:
# True

# %%
3 < 1 or 5<1
# Out:
# False

# %%
cpu_uses = 70
memory_uses = 95

cpu_uses > 90 or memory_uses > 90
# Out:
# True

# %%
email = True
password = False

email and password
# Out:
# False

# %%
email = True
password = True

email and password
# Out:
# True

# %%
email = False
password = False

email and password
# Out:
# False

# %% [markdown]
# ---
# - not Operators
#
# ---

# %%
3 > 2
# Out:
# True

# %%
not 3 > 2
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not not True
# Out:
# True

# %%
not not False
# Out:
# False

# %%
print(False == True)
# Out:
# False

# %%
print( 3 > 1 and 5  < 1)
# Out:
# False

# %%
3 > 1 and 5>1
# Out:
# True

# %%
cpu_uses = 70

memory_uses = 50

print(cpu_uses > 90 or memory_uses > 90)
# Out:
# False

# %%
email = True
password = False

email and password
# Out:
# False

# %%
email or password
# Out:
# True

# %% [markdown]
# ---
# ## Not Operator
# ---

# %%
print(not 3 > 2)
# Out:
# False

# %%
print(not True)
# Out:
# False

# %%
print(not False)
# Out:
# True

# %%
name = ""
print(not name)
# Out:
# True

# %%
print(not 0)
# Out:
# True

# %% [markdown]
# ---
# ## Control Execution Order
# ---

# %%
x = 5
y = 8
z = 4

# %%
5==5 or 8>5 and 6<4
# ------True and False
# True--or--False
# -----True
# Out:
# True
