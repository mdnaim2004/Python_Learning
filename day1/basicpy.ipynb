# %%
a = 7

if a > 5:
    print("5 er besi")
    print("koto besi k jane?")
else:
    print("chooto chooto raate lombi hoye")
# Out:
# 5 er besi
# koto besi k jane?

# %%
a = 2
if a > 3:
    print("5 er boro")
    print("koto boro k jane?")
elif a > 3:
    print("olpo boro")
elif a == 2:
    print("soman soman")
else:
    print("not exist")
# Out:
# soman soman

# %%
boss = False
if boss is True:
    print("ami astechi.")
else:
    print("pore asen.")
# Out:
# pore asen.

# %%
boss = False


if boss is not True:
    print("pore asen.")

else:
    print("ami astechi.")
# Out:
# pore asen.

# %%
coin ='head'
boss = True

if boss == True:
    print("boss you are joss")
    if coin == 'tail':
        print("batting")
    else:
        print("Bolling")
        if 9%2 == 1:
            print("odd number")
        else:
            print("Even number")
            if 5 > 2 or boss != True:
                print('do somthing.')
                if (8 % 2 == 0) and (5 % 2 == 0):
                    print("the number is even")
else:
    print("nestade ifelse.")
# Out:
# boss you are joss
# Bolling
# odd number

# %%
num = 1
while num <10:
    print(num)
    num = num+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
n = 1
while n <=10:
    print(n)
    n+=1
    if n == 5:
        break
        print("the program break")
# Out:
# 1
# 2
# 3
# 4

# %%
m = 1
while m <= 10:
    
    m+=1
    if m == 5:
        continue
    print(m)
# Out:
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10
# 11

# %%
t = 'pagla howa'
for char in t:
    print(char)
# Out:
# p
# a
# g
# l
# a
#
# h
# o
# w
# a

# %%
print(range(1,10))
# Out:
# range(1, 10)

# %%
for i in range(1, 10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
